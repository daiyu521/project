# %%
pip install lxml
# Out:
# ...
#      |████████████████████████████████| 5.8MB 6.7MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Read the HTML file

# %%
import pandas as pd
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
df = pd.read_html(url, header=0)[0]
df.head(20)
# Out:
#    Postal code           Borough  \
# 0          M1A      Not assigned
# 1          M2A      Not assigned
# 2          M3A        North York
# 3          M4A        North York
# 4          M5A  Downtown Toronto
# 5          M6A        North York
# 6          M7A  Downtown Toronto
# 7          M8A      Not assigned
# 8          M9A         Etobicoke
# 9          M1B       Scarborough
# 10         M2B      Not assigned
# 11         M3B        North York
# 12         M4B         East York
# 13         M5B  Downtown Toronto
# 14         M6B        North York
# 15         M7B      Not assigned
# 16         M8B      Not assigned
# 17         M9B         Etobicoke
# 18         M1C       Scarborough
# 19         M2C      Not assigned
#
#                                          Neighborhood
# 0                                                 NaN
# 1                                                 NaN
# 2                                           Parkwoods
# ...

# %% [markdown]
# Find Duplicated Data In Column Postal code

# %%
data=df.duplicated('Postal code') 
data.unique()
# Out:
# array([False])

# %% [markdown]
# Find Out The Data Type

# %%
print(df.dtypes)
# Out:
# Postal code     object
# Borough         object
# Neighborhood    object
# dtype: object

# %% [markdown]
# Find The Missing Data

# %%
missing_data = df.isnull()
missing_data.head(5)
# Out:
#    Postal code  Borough  Neighborhood
# 0        False    False          True
# 1        False    False          True
# 2        False    False         False
# 3        False    False         False
# 4        False    False         False

# %%
for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# Postal code
# False    180
# Name: Postal code, dtype: int64
#
# Borough
# False    180
# Name: Borough, dtype: int64
#
# Neighborhood
# False    103
# True      77
# Name: Neighborhood, dtype: int64

# %% [markdown]
# Drop The Missing Data

# %%
df.dropna(subset=["Neighborhood"], axis=0, inplace=True)
df.head()
# Out:
#   Postal code           Borough                                  Neighborhood
# 2         M3A        North York                                     Parkwoods
# 3         M4A        North York                              Victoria Village
# 4         M5A  Downtown Toronto                    Regent Park / Harbourfront
# 5         M6A        North York             Lawrence Manor / Lawrence Heights
# 6         M7A  Downtown Toronto  Queen's Park / Ontario Provincial Government

# %% [markdown]
# Replace "/" with "," in Column Neighborhood

# %%
df['Neighborhood'] = df['Neighborhood'].str.replace('/',',')
df.head()
# Out:
#   Postal code           Borough                                  Neighborhood
# 2         M3A        North York                                     Parkwoods
# 3         M4A        North York                              Victoria Village
# 4         M5A  Downtown Toronto                    Regent Park , Harbourfront
# 5         M6A        North York             Lawrence Manor , Lawrence Heights
# 6         M7A  Downtown Toronto  Queen's Park , Ontario Provincial Government

# %% [markdown]
# Reset The Index For The Dataframe

# %%
df.reset_index(drop=True)
# Out:
#     Postal code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# 5           M9A         Etobicoke
# 6           M1B       Scarborough
# 7           M3B        North York
# 8           M4B         East York
# 9           M5B  Downtown Toronto
# 10          M6B        North York
# 11          M9B         Etobicoke
# 12          M1C       Scarborough
# 13          M3C        North York
# 14          M4C         East York
# 15          M5C  Downtown Toronto
# 16          M6C              York
# 17          M9C         Etobicoke
# 18          M1E       Scarborough
# 19          M4E      East Toronto
# 20          M5E  Downtown Toronto
# 21          M6E              York
# 22          M1G       Scarborough
# 23          M4G         East York
# 24          M5G  Downtown Toronto
# 25          M6G  Downtown Toronto
# ...

# %% [markdown]
# Find the Numbers of Rows and Columns in the Dataframe

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# DownLoad the Geospatial csv file

# %%
# !wget -q -O 'Geospatial_data' http://cocl.us/Geospatial_data
print('Data downloaded!')
# Out:
# Data downloaded!

# %% [markdown]
# Read CSV file in Dataframe

# %%
df1 = pd.read_csv('Geospatial_data')

# %%
df1.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# Merge Two dataframe and delete the duplicated colume

# %%
df1['Postal code']=df1['Postal Code']
df3=pd.merge(df,df1,on='Postal code',how='right')
df3.drop('Postal Code', axis=1, inplace=True)

# %%
df3.head(20)
# Out:
#    Postal code           Borough  \
# 0          M3A        North York
# 1          M4A        North York
# 2          M5A  Downtown Toronto
# 3          M6A        North York
# 4          M7A  Downtown Toronto
# 5          M9A         Etobicoke
# 6          M1B       Scarborough
# 7          M3B        North York
# 8          M4B         East York
# 9          M5B  Downtown Toronto
# 10         M6B        North York
# 11         M9B         Etobicoke
# 12         M1C       Scarborough
# 13         M3C        North York
# 14         M4C         East York
# 15         M5C  Downtown Toronto
# 16         M6C              York
# 17         M9C         Etobicoke
# 18         M1E       Scarborough
# 19         M4E      East Toronto
#
#                                          Neighborhood   Latitude  Longitude
# 0                                           Parkwoods  43.753259 -79.329656
# 1                                    Victoria Village  43.725882 -79.315572
# ...
